# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyadivi/CASE2409/blob/main/priyaa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as reddy
x=['TDP','YSRCP','JSP','BJP']
y=[135,11,21,8]
z=['yellow','blue','red','orange']
reddy.bar(x,y,color=z)
reddy.xlabel('party')
reddy.ylabel('seats won')
reddy.show()

# %%
import matplotlib.pyplot as telangana
party=['CONGRESS','BJP','AIMIM','BRS']
X=[8,8,1,0]
Y=[3,4,1,9]
telangana.plot(party,X,color='violet')
telangana.plot(party,Y,color='pink')
telangana.title('2019 vs 2024')
telangana.show()

# %%
import matplotlib.pyplot as BRAMHANANDAM
data_2013=[7,3,8]
data_2014=[4,2,10]
data_2015=[6,8,4]
actress=['trisha','kajal','anushka']
data=[data_2013,data_2014,data_2015]

# %%
import matplotlib.pyplot as mouli
movie=['stu no 1','YAMADONGA','MARYADA RAMANNA','EEGA','RRR']
budget=[12,40,30,120,1200]
mouli.pie(budget,labels=movie)
#donut chart
ravi=mouli.Circle((0,0),0.5,color='white')
mouli.gca().add_artist(ravi)
mouli.show()

# %%
import matplotlib.pyplot as HOD
data=[1,2,7,7,8,1,2,7,8,8,8,10]
#histogram
HOD.hist(data,bins=10,color='green')
HOD.title('SIGNAL & SYSTEMS')
HOD.xlabel('marks')
HOD.ylabel('count')
HOD.show()

# %%
import numpy as HARSHA
a=[1,2,2,1,100,420]

# %%
import pandas as EdaYildiz
MB=EdaYildiz.read_csv('mahesh.csv')
print(MB)
# Out:
#           MOVIE       STATUS         GENRE            ACTRESS
# 0        Pokiri  Blockbuster        Action     T. Ileana Cruz
# 1        Athadu  Blockbuster        Action             Trisha
# 2   Businessman  Blockbuster  Action-crime              Kajal
# 3   Srimanthudu  Blockbuster  Action-drama      Shruti Haasan
# 4        Spyder          Hit  Spy thriller  Rakul Preet Singh
# 5  Brahmotsavam      Average  Family-drama              Kajal

# %%
import pandas as EdaYildiz
babu=EdaYildiz.read_csv('mahesh.csv')
#print(babu)
#actress
#print(babu['ACTRESS])
print(babu.shape)
# Out:
# (6, 4)

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("17.jfif.jpg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: police
# Confidence Score: 0.9999981
